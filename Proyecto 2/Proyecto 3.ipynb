# %% [markdown]
# $Equipo: Daniel Navarro Hernandez, Iñaki Sebastián Orozco García$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
alternative = pd.read_csv("./data/alternative_music_data.csv")
blues = pd.read_csv("./data/blues_music_data.csv")
hiphop = pd.read_csv("./data/hiphop_music_data.csv")
indie_alt = pd.read_csv("./data/indie_alt_music_data.csv")
metal = pd.read_csv("./data/metal_music_data.csv")
pop = pd.read_csv("./data/pop_music_data.csv")
rock = pd.read_csv("./data/rock_music_data.csv")

# %% [markdown]
# ### Agregamos el género a los data frames:

# %% [markdown]
# 1. alternative
# 2. blues
# 3. hiphop
# 4. indie alt
# 5. metal
# 6. pop
# 7. rock

# %%
labels = []
for x in range(alternative.shape[0]):
    labels.append(1)
alternative["labels"] = labels

labels = []
for x in range(blues.shape[0]):
    labels.append(2)
blues["labels"] = labels

labels = []
for x in range(hiphop.shape[0]):
    labels.append(3)
hiphop["labels"] = labels

labels = []
for x in range(indie_alt.shape[0]):
    labels.append(4)
indie_alt["labels"] = labels

labels = []
for x in range(metal.shape[0]):
    labels.append(4)
metal["labels"] = labels

labels = []
for x in range(pop.shape[0]):
    labels.append(5)
pop["labels"] = labels

labels = []
for x in range(rock.shape[0]):
    labels.append(4)
rock["labels"] = labels

# %% [markdown]
# ### Juntamos los data frames

# %%
data = alternative
data.append(blues)
data.append(hiphop)
data.append(indie_alt)
data.append(metal)
data.append(pop)
data.append(rock)
dataNoFilter = data

# %% [markdown]
# ### Filtramos la información necesaria para entrenar los modelos:

# %%
data.drop(["Artist Name", "Track Name", "Genres", "Playlist", "id", "uri", "track_href", "analysis_url"], axis=1)
# Out:
#       Popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0             66         0.457   0.909    0    -9.451     1       0.0317
# 1             60         0.582   0.817    0    -6.475     1       0.0399
# 2             51         0.525   0.976    0    -2.023     1       0.0479
# 3             47         0.210   0.870    5    -5.985     1       0.0606
# 4             57         0.692   0.799    1    -7.924     1       0.1640
# ...          ...           ...     ...  ...       ...   ...          ...
# 2155          51         0.462   0.754    7    -3.361     1       0.0459
# 2156          54         0.521   0.855    9    -3.348     1       0.0686
# 2157          53         0.679   0.111    6   -28.013     1       0.0653
# 2158          27         0.426   0.538   10    -8.154     1       0.0367
# 2159          23         0.495   0.844    7    -4.448     1       0.0433
#
#       acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0         0.001600          0.000276    0.1350    0.755  115.998       156667
# 1         0.001700          0.015800    0.5750    0.622  155.124       198366
# 2         0.066200          0.000392    0.0804    0.855  138.984       192695
# 3         0.000147          0.000488    0.1880    0.517  168.352       264067
# 4         0.388000          0.000000    0.3010    0.549   97.978       199667
# ...            ...               ...       ...      ...      ...          ...
# 2155      0.008430          0.000000    0.1180    0.475  110.397       168533
# 2156      0.022300          0.000006    0.0869    0.257  158.744       187133
# 2157      0.623000          0.274000    0.3530    0.508   90.014       196000
# 2158      0.007510          0.003100    0.0729    0.507  171.693       228507
# 2159      0.000097          0.810000    0.4470    0.460  119.958       185916
#
#       time_signature  labels
# 0                  4       1
# 1                  4       1
# 2                  4       1
# 3                  4       1
# 4                  4       1
# ...              ...     ...
# 2155               3       1
# 2156               4       1
# 2157               4       1
# 2158               4       1
# 2159               4       1
#
# [2160 rows x 15 columns]

# %% [markdown]
# ### Iniciamos la separación de los datos para el entrenamiento

# %%
X = data

# %%
X_train, X_test, y_train, y_test = train_test_split(Xdata, ydata, test_size=0.3, random_state = 1)
